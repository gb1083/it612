# %% [markdown]
# <a href="https://colab.research.google.com/github/gb1083/it612/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile code.js
# console.log("hello world")
# function addTax(price, rate) {
#   return price + price * rate;
# }
# console.log(addTax(100, 0.1));
# console.log(addTax(100, 0.08));
#
# createBurner(secret, limit) {
#   let burned = 0;
#
#   return function ()
#   return()
# }
# Out:
# Overwriting code.js

# %%
# !node code.js
# Out:
# hello world
# 110
# 108

# %%
from google.colab import drive
drive.mount('/content/drive')
